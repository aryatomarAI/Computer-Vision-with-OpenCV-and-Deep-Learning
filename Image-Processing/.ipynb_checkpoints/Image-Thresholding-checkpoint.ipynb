# %% [markdown]
# ## Image Thresholding

# %% [markdown]
# * Thresholding is fundamentally a very simple method of segmenting an image into different parts.
# * Thresholding will convert an image to other image which consist of only two values, white and black

# %% [markdown]
# ### Simple Thresholding
# Here, the matter is straight-forward. For every pixel, the same threshold value is applied. If the pixel value is smaller than the threshold, it is set to 0, otherwise it is set to a maximum value. The function cv.threshold is used to apply the thresholding. The first argument is the source image, which should be a grayscale image. The second argument is the threshold value which is used to classify the pixel values. The third argument is the maximum value which is assigned to pixel values exceeding the threshold. OpenCV provides different types of thresholding which is given by the fourth parameter of the function.

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
rainbow_img=cv2.imread("rainbow.jpg",0)
plt.imshow(rainbow_img,cmap='gray')

# %% [markdown]
# ### Different Threshold types
# **Binary**

# %%
ret,thresh1=cv2.threshold(rainbow_img,127,255,cv2.THRESH_BINARY)

# %%
ret
# Out:
# 127.0

# %%
plt.imshow(thresh1,cmap='gray')

# %% [markdown]
# **Binary Inverse**

# %%
ret,thresh2=cv2.threshold(rainbow_img,127,255,cv2.THRESH_BINARY_INV)
ret
# Out:
# 127.0

# %%
plt.imshow(thresh2,cmap='gray')

# %% [markdown]
# **Threshold Truncation**

# %%
ret,thresh3=cv2.threshold(rainbow_img,127,255,cv2.THRESH_TRUNC)
plt.imshow(thresh3,cmap='gray')

# %% [markdown]
# **Threshold to zero**

# %%
ret,thresh4=cv2.threshold(rainbow_img,127,255,cv2.THRESH_TOZERO)
plt.imshow(thresh4,cmap='gray')

# %% [markdown]
# **Threshold to zero (inversion)**

# %%
ret,thresh5=cv2.threshold(rainbow_img,127,255,cv2.THRESH_TOZERO_INV)
plt.imshow(thresh5,cmap='gray')

# %% [markdown]
# ### Real World Appliaction
# **Adaptive Threshold**

# %%
img2=cv2.imread("crossword.jpg")
fix_img=cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)
plt.imshow(fix_img)

# %%
def show_pic(img):
    fig=plt.figure(figsize=(10,15))
    ax=fig.add_subplot(111)
    ax.imshow(img,cmap='gray')

# %%
show_pic(fix_img)

# %%
img_cross=cv2.imread('crossword.jpg',0)
show_pic(img_cross)

# %% [markdown]
# **Simple Binary**

# %%
ret,th=cv2.threshold(img_cross,127,255,cv2.THRESH_BINARY)
show_pic(th)

# %% [markdown]
# **Adaptive Theshold**

# %% [markdown]
# In the simple threshold, we used one global value as a threshold. But this might not be good in all cases, e.g. if an image has different lighting conditions in different areas. In that case, adaptive thresholding can help. Here, the algorithm determines the threshold for a pixel based on a small region around it. So we get different thresholds for different regions of the same image which gives better results for images with varying illumination.
#
#     @param src Source 8-bit single-channel image.
#         .   @param dst Destination image of the same size and the same type as src.
#         .   @param maxValue Non-zero value assigned to the pixels for which the condition is satisfied
#         .   @param adaptiveMethod Adaptive thresholding algorithm to use, see #AdaptiveThresholdTypes.
#         .   The #BORDER_REPLICATE | #BORDER_ISOLATED is used to process boundaries.
#         .   @param thresholdType Thresholding type that must be either #THRESH_BINARY or #THRESH_BINARY_INV,
#         .   see #ThresholdTypes.
#         .   @param blockSize Size of a pixel neighborhood that is used to calculate a threshold value for the
#         .   pixel: 3, 5, 7, and so on.
#         .   @param C Constant subtracted from the mean or weighted mean (see the details below). Normally, it
#         .   is positive but may be zero or negative as well.

# %%
th2=cv2.adaptiveThreshold(img_cross,240,cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,11,9)
show_pic(th2)

# %%
th3=cv2.adaptiveThreshold(img_cross,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,11,9)
show_pic(th3)

# %%
# Blend together two threshold images
blend=cv2.addWeighted(src1=th,alpha=0.7,src2=th2,beta=0.4,gamma=0)
show_pic(blend)
